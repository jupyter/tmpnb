# %% [markdown]
# ## Welcome to the Temporary Notebook (tmpnb) service!
#
# This Jupyter Notebook Server was **launched just for you**. It's a temporary way for you to try out the Jupyter notebook from the current development version.
#
#
# <div class="alert alert-warning" role="alert" style="margin: 10px">
# **WARNING:** Don't rely on this server for anything you want to last or anything private. The notebooks are publicly accessible - that's how you got here! This is also a basic prototype, so unexpected things might happen.
# </div>
#
# Feel free to run some code, make some plots, and play at your leisure!

# %% [markdown]
# ### Python!

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib

from matplotlib import pyplot as plt
import seaborn as sns

ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()

df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                  columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
plt.figure(); df.plot(); plt.legend(loc='best')

# %% [markdown]
# <center><h2>Behind the Scenes</h2>
# </center>

# %% [markdown]
# The service you're using is called [tmpnb](https://github.com/jupyter/tmpnb), a simple Tornado application that spawns [pre-built Docker containers](https://github.com/ipython/docker-notebook) in a few seconds (Thanks [Docker](https://docker.com)!) and then uses the [jupyter/configurable-http-proxy](https://github.com/jupyter/configurable-http-proxy) to put your notebook server on a unique path.
#
# The entire setup is hosted on an [OnMetal server](http://bit.ly/onmetal), an on-demand bare metal server at [Rackspace](http://bit.ly/tmpnbdevplus).
